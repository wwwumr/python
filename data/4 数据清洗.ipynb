# %% [markdown]
# <h1, align=center> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;数据科学引论 - Python之道 </h1>
#
# <h1, align=center> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;第4课 数据清洗 </h1>

# %% [markdown]
# <hr>

# %% [markdown]
# <h1, align="center">按国家和年份统计的CO2排放量</h1>

# %% [markdown]
# 二氧化碳排放源自燃烧化石燃料和水泥制造，包含了在固体、液体和气体燃料消耗以及放空燃烧过程中所产生的二氧化碳

# %% [markdown]
# http://data.worldbank.org/indicator/EN.ATM.CO2E.PC/

# %% [markdown]
# <h2, align=center>获取数据</h2>

# %% [markdown]
# 这些数据可以从世界银行(World Bank) [链接](http://data.worldbank.org/indicator/EN.ATM.CO2E.PC/) 或者从 Box [链接](https://ibm.box.com/shared/static/3yzxbbizo49bkl8cnjw15tymzfwkycj4.csv) 上下载

# %% [markdown]
# #### 我们在linux下可以使用bash命令 `wget` 从链接处获取 csv 文件

# %%
# !wget --output-document /resources/data/co2emissions.csv https://ibm.box.com/shared/static/3yzxbbizo49bkl8cnjw15tymzfwkycj4.csv

# %% [markdown]
# <hr>

# %% [markdown]
# <h2, align=center>使用 Pandas 导入数据</h2>

# %% [markdown]
# #### 导入所需的 `pandas` 库

# %%
import pandas as pd

# %% [markdown]
# #### 使用 `pd.read_csv` 导入数据

# %%
data = pd.read_csv("resources/data/co2emissions.csv", skiprows = 4)

# %% [markdown]
# #### 使用 `head` 显示 `data`  的前5行

# %%
data
# Out:
#                        Country Name Country Code  \
# 0                             Aruba          ABW
# 1                           Andorra          AND
# 2                       Afghanistan          AFG
# 3                            Angola          AGO
# 4                           Albania          ALB
# 5                        Arab World          ARB
# 6              United Arab Emirates          ARE
# 7                         Argentina          ARG
# 8                           Armenia          ARM
# 9                    American Samoa          ASM
# 10              Antigua and Barbuda          ATG
# 11                        Australia          AUS
# 12                          Austria          AUT
# 13                       Azerbaijan          AZE
# 14                          Burundi          BDI
# 15                          Belgium          BEL
# 16                            Benin          BEN
# 17                     Burkina Faso          BFA
# 18                       Bangladesh          BGD
# 19                         Bulgaria          BGR
# 20                          Bahrain          BHR
# 21                     Bahamas, The          BHS
# 22           Bosnia and Herzegovina          BIH
# 23                          Belarus          BLR
# 24                           Belize          BLZ
# 25                          Bermuda          BMU
# 26                          Bolivia          BOL
# 27                           Brazil          BRA
# 28                         Barbados          BRB
# 29                Brunei Darussalam          BRN
# ..                              ...          ...
# 219                        Thailand          THA
# 220                      Tajikistan          TJK
# 221                    Turkmenistan          TKM
# 222                     Timor-Leste          TLS
# 223                           Tonga          TON
# 224             Trinidad and Tobago          TTO
# 225                         Tunisia          TUN
# 226                          Turkey          TUR
# 227                          Tuvalu          TUV
# 228                   Taiwan, China          TWN
# 229                        Tanzania          TZA
# 230                          Uganda          UGA
# 231                         Ukraine          UKR
# 232             Upper middle income          UMC
# 233                         Uruguay          URY
# 234                   United States          USA
# 235                      Uzbekistan          UZB
# 236  St. Vincent and the Grenadines          VCT
# 237                   Venezuela, RB          VEN
# 238           Virgin Islands (U.S.)          VIR
# 239                         Vietnam          VNM
# 240                         Vanuatu          VUT
# 241              West Bank and Gaza          PSE
# 242                           World          WLD
# 243                           Samoa          WSM
# 244                     Yemen, Rep.          YEM
# 245                    South Africa          ZAF
# 246                Congo, Dem. Rep.          COD
# 247                          Zambia          ZMB
# 248                        Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code       1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.046068
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.104357
# 4    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.258195
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.643964
# 6    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.118786
# 7    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.367473
# 8    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 9    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 10   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.670617
# 11   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   8.582937
# 12   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.373319
# 13   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 14   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 15   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   9.941594
# 16   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.066354
# 17   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.009112
# 18   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 19   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.833901
# 20   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.542864
# 21   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.749831
# 22   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 23   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 24   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.477951
# 25   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.551374
# 26   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.272038
# 27   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.647068
# 28   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.746313
# 29   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.078179
# ..                                      ...             ...        ...
# 219  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135586
# 220  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 221  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 222  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 223  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.178588
# 224  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.042576
# 225  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.409211
# 226  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.610473
# 227  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 228  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 229  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.082261
# 230  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.062123
# 231  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 232  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.288256
# 233  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.701583
# 234  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  15.999779
# 235  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 236  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135902
# 237  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   7.005107
# 238  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 239  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.215631
# 240  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 241  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 242  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.096144
# 243  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135009
# 244  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.703403
# 245  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   5.629718
# 246  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.152228
# 247  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 248  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
#
#           1961       1962       1963       1964       1965     ...       \
# 0          NaN        NaN        NaN        NaN        NaN     ...
# 1          NaN        NaN        NaN        NaN        NaN     ...
# 2     0.053615   0.073781   0.074251   0.086317   0.101499     ...
# 3     0.084718   0.216025   0.206877   0.216174   0.206089     ...
# 4     1.374186   1.439956   1.181681   1.111742   1.166099     ...
# 5     0.685501   0.761148   0.875124   0.999248   1.166075     ...
# 6     0.108937   0.163355   0.175712   0.132651   0.146370     ...
# 7     2.442616   2.522392   2.316356   2.538380   2.641714     ...
# 8          NaN        NaN        NaN        NaN        NaN     ...
# 9          NaN        NaN        NaN        NaN        NaN     ...
# 10    0.860441   1.823374   1.470175   1.567094   2.520359     ...
# 11    8.641569   8.835688   9.226440   9.759073  10.622321     ...
# 12    4.496362   4.755362   5.155194   5.391004   5.252197     ...
# 13         NaN        NaN        NaN        NaN        NaN     ...
# 14         NaN   0.015203   0.016155   0.015827   0.011910     ...
# 15   10.103872  10.641190  11.386929  11.053655  11.141656     ...
# 16    0.052046   0.054202   0.047580   0.055295   0.057115     ...
# 17    0.018730   0.017003   0.017504   0.021575   0.019841     ...
# 18         NaN        NaN        NaN        NaN        NaN     ...
# 19    3.269920   3.835892   4.259781   5.262988   5.645652     ...
# 20   10.547396   9.193609   6.714156   8.747480   6.557022     ...
# 21    4.746699   5.996432   5.558199   8.118597   9.399946     ...
# 22         NaN        NaN        NaN        NaN        NaN     ...
# 23         NaN        NaN        NaN        NaN        NaN     ...
# 24    0.387219   0.715409   0.622357   0.818289   0.794763     ...
# 25    3.868484   3.383712   3.151929   4.124438   3.586487     ...
# 26    0.276621   0.286626   0.310159   0.371216   0.371151     ...
# 239   1.352791   1.497496   1.636371   1.761695   1.971889   NaN   NaN   NaN
# 240   0.433459   0.406839   0.508463   0.496591   0.591266   NaN   NaN   NaN
# 241   0.665297   0.570947   0.564578   0.534015   0.572407   NaN   NaN   NaN
# 242   4.686122   4.741826   4.663120   4.840436   4.944676   NaN   NaN   NaN
# 243   1.026224   1.039490   1.072106   1.103871   1.252110   NaN   NaN   NaN
# 244   0.981422   0.989905   1.026251   1.090060   0.919968   NaN   NaN   NaN
# 245   9.063326   9.506481   9.545495   8.957154   9.257216   NaN   NaN   NaN
# 246   0.047312   0.048411   0.045604   0.049328   0.050303   NaN   NaN   NaN
# 247   0.150265   0.164692   0.184058   0.192079   0.212450   NaN   NaN   NaN
# 248   0.731867   0.569255   0.600521   0.646073   0.691698   NaN   NaN   NaN
#
#      2015  Unnamed: 60
# 0     NaN          NaN
# 1     NaN          NaN
# 2     NaN          NaN
# 3     NaN          NaN
# 4     NaN          NaN
# 5     NaN          NaN
# 6     NaN          NaN
# 7     NaN          NaN
# 8     NaN          NaN
# 9     NaN          NaN
# 10    NaN          NaN
# 11    NaN          NaN
# 12    NaN          NaN
# 13    NaN          NaN
# 14    NaN          NaN
# 15    NaN          NaN
# 16    NaN          NaN
# 17    NaN          NaN
# 18    NaN          NaN
# 19    NaN          NaN
# 20    NaN          NaN
# 21    NaN          NaN
# 22    NaN          NaN
# 23    NaN          NaN
# 24    NaN          NaN
# 25    NaN          NaN
# 26    NaN          NaN
# 27    NaN          NaN
# 28    NaN          NaN
# 29    NaN          NaN
# ..    ...          ...
# 219   NaN          NaN
# 220   NaN          NaN
# 221   NaN          NaN
# 222   NaN          NaN
# 223   NaN          NaN
# 224   NaN          NaN
# 225   NaN          NaN
# 226   NaN          NaN
# 227   NaN          NaN
# 228   NaN          NaN
# 229   NaN          NaN
# 230   NaN          NaN
# 231   NaN          NaN
# 232   NaN          NaN
# 233   NaN          NaN
# 234   NaN          NaN
# 235   NaN          NaN
# 236   NaN          NaN
# 237   NaN          NaN
# 238   NaN          NaN
# 239   NaN          NaN
# 240   NaN          NaN
# 241   NaN          NaN
# 242   NaN          NaN
# 243   NaN          NaN
# 244   NaN          NaN
# 245   NaN          NaN
# 246   NaN          NaN
# 247   NaN          NaN
# 248   NaN          NaN
#
# [249 rows x 61 columns]

# %% [markdown]
# <h1, align=center>数据清洗</h1>

# %% [markdown]
# #### 观察这些数据，其质量有什么问题？我们应该如何解决这些问题？

# %% [markdown]
# 例如，下面这些行有什么问题？

# %%
data.loc[[9,182,220,242]]
# Out:
#        Country Name Country Code                          Indicator Name  \
# 9    American Samoa          ASM  CO2 emissions (metric tons per capita)
# 182     Puerto Rico          PRI  CO2 emissions (metric tons per capita)
# 220      Tajikistan          TJK  CO2 emissions (metric tons per capita)
# 242           World          WLD  CO2 emissions (metric tons per capita)
#
#      Indicator Code      1960      1961     1962      1963      1964  \
# 9    EN.ATM.CO2E.PC       NaN       NaN      NaN       NaN       NaN
# 182  EN.ATM.CO2E.PC       NaN       NaN      NaN       NaN       NaN
# 220  EN.ATM.CO2E.PC       NaN       NaN      NaN       NaN       NaN
# 242  EN.ATM.CO2E.PC  3.096144  3.067062  3.13802  3.242364  3.358696
#
#          1965     ...           2007      2008      2009      2010      2011  \
# 9         NaN     ...            NaN       NaN       NaN       NaN       NaN
# 182       NaN     ...            NaN       NaN       NaN       NaN       NaN
# 220       NaN     ...       0.463345  0.409462  0.382775  0.373873  0.358948
# 242  3.437595     ...       4.686122  4.741826  4.663120  4.840436  4.944676
#
#      2012  2013  2014  2015  Unnamed: 60
# 9     NaN   NaN   NaN   NaN          NaN
# 182   NaN   NaN   NaN   NaN          NaN
# 220   NaN   NaN   NaN   NaN          NaN
# 242   NaN   NaN   NaN   NaN          NaN
#
# [4 rows x 61 columns]

# %% [markdown]
# ## 数据质量的问题:
# 1. 有些行是多个国家的总和，而不是实际的国家(例如, "World").
# 2. 有些列是不相关的，可以被移除(例如, "Indicator Name").
# 3. 有些年份对于任何国家都没有数据(例如, 2015 到 2016).
# 4. 有些国家在任何年份都没有数据(例如, "American Samoa").

# %% [markdown]
# <br>

# %% [markdown]
# <h2> 1. 有些行是多个国家的总和，而不是实际的国家 (例如, "World"). </h2>
#
# **目标:**
# 移除不包含实际国家的行。幸运的是，世界银行(World Bank)提供了相应的元数据，表明了哪些行是国家，而哪些行是多个国家的总和。
# - 导入countries_metadata.csv
# - 在`Country Code`上将元数据与`data`合并

# %% [markdown]
# #### 获取 `countries_metadata.csv`

# %%
# !wget --output-document /resources/data/countries_metadata.csv https://ibm.box.com/shared/static/qh3o86mpij17ot7anydcmbwt41lwxvln.csv

# %% [markdown]
# #### 导入 `countries_metadata.csv`

# %%
metadata = pd.read_csv("resources/data/countries_metadata.csv", encoding = "utf-8")

# %%
metadata.head(10)
# Out:
#            Country Name Country Code                      Region  \
# 0                 Aruba          ABW   Latin America & Caribbean
# 1           Afghanistan          AFG                  South Asia
# 2                Angola          AGO          Sub-Saharan Africa
# 3               Albania          ALB       Europe & Central Asia
# 4               Andorra          AND       Europe & Central Asia
# 5            Arab World          ARB                         NaN
# 6  United Arab Emirates          ARE  Middle East & North Africa
# 7             Argentina          ARG   Latin America & Caribbean
# 8               Armenia          ARM       Europe & Central Asia
# 9        American Samoa          ASM         East Asia & Pacific
#
#             IncomeGroup                                       SpecialNotes  \
# 0  High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1            Low income  Fiscal year end: March 20; reporting period fo...
# 2   Upper middle income  April 2013 database update: Based on IMF data,...
# 3   Upper middle income                                                NaN
# 4  High income: nonOECD                                                NaN
# 5                   NaN  Arab World aggregate. Arab World is composed o...
# 6  High income: nonOECD  April 2013 database update: Based on data from...
# 7  High income: nonOECD                 The base year has changed to 2004.
# 8   Lower middle income                                                NaN
# 9   Upper middle income                                                NaN
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %% [markdown]
# #### 如何标识列出的"Country Name" 是一个国家还是一个多国构成的区域?

# %% [markdown]
# 注意，当某一行是像"Arab World"这样的聚合区域时,  `Region` 和 `IncomeGroup` 总是 NaN (Not a Number). 我们可以用这条规则来移除所有不是国家的区域.

# %% [markdown]
# #### 在关键字`Country Code`上合并`data` 与 `metadata`

# %%
merge = pd.merge(data, metadata, on = "Country Code")

# %%
merge
# Out:
#                      Country Name_x Country Code  \
# 0                             Aruba          ABW
# 1                           Andorra          AND
# 2                       Afghanistan          AFG
# 3                            Angola          AGO
# 4                           Albania          ALB
# 5                        Arab World          ARB
# 6              United Arab Emirates          ARE
# 7                         Argentina          ARG
# 8                           Armenia          ARM
# 9                    American Samoa          ASM
# 10              Antigua and Barbuda          ATG
# 11                        Australia          AUS
# 12                          Austria          AUT
# 13                       Azerbaijan          AZE
# 14                          Burundi          BDI
# 15                          Belgium          BEL
# 16                            Benin          BEN
# 17                     Burkina Faso          BFA
# 18                       Bangladesh          BGD
# 19                         Bulgaria          BGR
# 20                          Bahrain          BHR
# 21                     Bahamas, The          BHS
# 22           Bosnia and Herzegovina          BIH
# 23                          Belarus          BLR
# 24                           Belize          BLZ
# 25                          Bermuda          BMU
# 26                          Bolivia          BOL
# 27                           Brazil          BRA
# 28                         Barbados          BRB
# 29                Brunei Darussalam          BRN
# ..                              ...          ...
# 218                        Thailand          THA
# 219                      Tajikistan          TJK
# 220                    Turkmenistan          TKM
# 221                     Timor-Leste          TLS
# 222                           Tonga          TON
# 223             Trinidad and Tobago          TTO
# 224                         Tunisia          TUN
# 225                          Turkey          TUR
# 226                          Tuvalu          TUV
# 227                   Taiwan, China          TWN
# 228                        Tanzania          TZA
# 229                          Uganda          UGA
# 230                         Ukraine          UKR
# 231             Upper middle income          UMC
# 232                         Uruguay          URY
# 233                   United States          USA
# 234                      Uzbekistan          UZB
# 235  St. Vincent and the Grenadines          VCT
# 236                   Venezuela, RB          VEN
# 237           Virgin Islands (U.S.)          VIR
# 238                         Vietnam          VNM
# 239                         Vanuatu          VUT
# 240              West Bank and Gaza          PSE
# 241                           World          WLD
# 242                           Samoa          WSM
# 243                     Yemen, Rep.          YEM
# 244                    South Africa          ZAF
# 245                Congo, Dem. Rep.          COD
# 246                          Zambia          ZMB
# 247                        Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code       1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.046068
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.104357
# 4    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.258195
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.643964
# 6    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.118786
# 7    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.367473
# 8    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 9    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 10   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.670617
# 11   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   8.582937
# 12   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.373319
# 13   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 14   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 15   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   9.941594
# 16   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.066354
# 17   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.009112
# 18   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 19   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.833901
# 20   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.542864
# 21   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.749831
# 22   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 23   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 24   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.477951
# 25   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.551374
# 26   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.272038
# 27   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.647068
# 28   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.746313
# 29   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.078179
# ..                                      ...             ...        ...
# 218  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135586
# 219  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 220  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 221  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 222  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.178588
# 223  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.042576
# 224  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.409211
# 225  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.610473
# 226  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 227  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 228  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.082261
# 229  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.062123
# 230  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 231  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.288256
# 232  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.701583
# 233  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  15.999779
# 234  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 235  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135902
# 236  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   7.005107
# 237  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 238  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.215631
# 239  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 240  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 241  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.096144
# 242  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135009
# 243  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.703403
# 244  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   5.629718
# 245  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.152228
# 246  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 247  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
#
#           1961       1962       1963       1964       1965     ...      2012  \
# 0          NaN        NaN        NaN        NaN        NaN     ...       NaN
# 1          NaN        NaN        NaN        NaN        NaN     ...       NaN
# 2     0.053615   0.073781   0.074251   0.086317   0.101499     ...       NaN
# 3     0.084718   0.216025   0.206877   0.216174   0.206089     ...       NaN
# 4     1.374186   1.439956   1.181681   1.111742   1.166099     ...       NaN
# 5     0.685501   0.761148   0.875124   0.999248   1.166075     ...       NaN
# 6     0.108937   0.163355   0.175712   0.132651   0.146370     ...       NaN
# 7     2.442616   2.522392   2.316356   2.538380   2.641714     ...       NaN
# 8          NaN        NaN        NaN        NaN        NaN     ...       NaN
# 9          NaN        NaN        NaN        NaN        NaN     ...       NaN
# 10    0.860441   1.823374   1.470175   1.567094   2.520359     ...       NaN
# 11    8.641569   8.835688   9.226440   9.759073  10.622321     ...       NaN
# 12    4.496362   4.755362   5.155194   5.391004   5.252197     ...       NaN
# 13         NaN        NaN        NaN        NaN        NaN     ...       NaN
# 14         NaN   0.015203   0.016155   0.015827   0.011910     ...       NaN
# 15   10.103872  10.641190  11.386929  11.053655  11.141656     ...       NaN
# 16    0.052046   0.054202   0.047580   0.055295   0.057115     ...       NaN
# 17    0.018730   0.017003   0.017504   0.021575   0.019841     ...       NaN
# 18         NaN        NaN        NaN        NaN        NaN     ...       NaN
# 19    3.269920   3.835892   4.259781   5.262988   5.645652     ...       NaN
# 20   10.547396   9.193609   6.714156   8.747480   6.557022     ...       NaN
# 21    4.746699   5.996432   5.558199   8.118597   9.399946     ...       NaN
# 22         NaN        NaN        NaN        NaN        NaN     ...       NaN
# 23         NaN        NaN        NaN        NaN        NaN     ...       NaN
# 24    0.387219   0.715409   0.622357   0.818289   0.794763     ...       NaN
# 25    3.868484   3.383712   3.151929   4.124438   3.586487     ...       NaN
# 26    0.276621   0.286626   0.310159   0.371216   0.371151     ...       NaN
# 27    0.658625   0.697281   0.700749   0.694001   0.670372     ...       NaN
# 28    0.838899   1.119411   0.816330   0.766085   0.872454     ...       NaN
# 29    3.552009   4.133422   3.798174   3.482289   3.254787     ...       NaN
# ..         ...        ...        ...        ...        ...     ...       ...
# 218   0.146944   0.173130   0.185877   0.242240   0.234151     ...       NaN
# 219        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 220        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 221        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 222   0.172592   0.166040   0.159435   0.153309   0.147936     ...       NaN
# 223   5.318141   8.225570   1.466683   4.201774   5.694904     ...       NaN
# 224   0.413220   0.412987   0.438885   0.608626   0.532230     ...       NaN
# 225   0.615079   0.748241   0.765934   0.869390   0.883506     ...       NaN
# 226        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 227        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 228   0.067872   0.071734   0.072968   0.091197   0.099494     ...       NaN
# 229   0.058093   0.059258   0.057791   0.063435   0.078242     ...       NaN
# 230        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 231   1.057435   0.957318   0.955719   0.982914   1.036033     ...       NaN
# 232   1.602723   1.540657   1.639285   1.710101   2.049519     ...       NaN
# 233  15.681256  16.013937  16.482762  16.968119  17.451725     ...       NaN
# 234        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 235   0.133923   0.132214   0.174273   0.215513   0.170614     ...       NaN
# 236   6.136886   6.155057   6.155748   5.973226   6.187252     ...       NaN
# 237        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 238   0.225435   0.258760   0.247579   0.314058   0.343354     ...       NaN
# 239        NaN   0.594888   0.471728   0.864247   0.641714     ...       NaN
# 240        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 241   3.067062   3.138020   3.242364   3.358696   3.437595     ...       NaN
# 242   0.163529   0.158352   0.184019   0.208092   0.230869     ...       NaN
# 243   0.507631   0.728004   0.537606   0.658012   0.699574     ...       NaN
# 244   5.694383   5.729712   5.799844   6.170936   6.467359     ...       NaN
# 245   0.150782   0.135559   0.139446   0.116926   0.142290     ...       NaN
# 246        NaN        NaN        NaN   0.950434   1.100197     ...       NaN
# 247        NaN        NaN        NaN   1.045374   1.179176     ...       NaN
#
#      2013  2014  2015  Unnamed: 60                  Country Name_y  \
# 0     NaN   NaN   NaN          NaN                           Aruba
# 1     NaN   NaN   NaN          NaN                         Andorra
# 2     NaN   NaN   NaN          NaN                     Afghanistan
# 3     NaN   NaN   NaN          NaN                          Angola
# 4     NaN   NaN   NaN          NaN                         Albania
# 5     NaN   NaN   NaN          NaN                      Arab World
# 6     NaN   NaN   NaN          NaN            United Arab Emirates
# 7     NaN   NaN   NaN          NaN                       Argentina
# 8     NaN   NaN   NaN          NaN                         Armenia
# 9     NaN   NaN   NaN          NaN                  American Samoa
# 10    NaN   NaN   NaN          NaN             Antigua and Barbuda
# 11    NaN   NaN   NaN          NaN                       Australia
# 12    NaN   NaN   NaN          NaN                         Austria
# 13    NaN   NaN   NaN          NaN                      Azerbaijan
# 14    NaN   NaN   NaN          NaN                         Burundi
# 15    NaN   NaN   NaN          NaN                         Belgium
# 16    NaN   NaN   NaN          NaN                           Benin
# 17    NaN   NaN   NaN          NaN                    Burkina Faso
# 18    NaN   NaN   NaN          NaN                      Bangladesh
# 19    NaN   NaN   NaN          NaN                        Bulgaria
# 20    NaN   NaN   NaN          NaN                         Bahrain
# 21    NaN   NaN   NaN          NaN                    Bahamas, The
# 22    NaN   NaN   NaN          NaN          Bosnia and Herzegovina
# 23    NaN   NaN   NaN          NaN                         Belarus
# 24    NaN   NaN   NaN          NaN                          Belize
# 25    NaN   NaN   NaN          NaN                         Bermuda
# 26    NaN   NaN   NaN          NaN                         Bolivia
# 27    NaN   NaN   NaN          NaN                          Brazil
# 28    NaN   NaN   NaN          NaN                        Barbados
# 29    NaN   NaN   NaN          NaN               Brunei Darussalam
# ..    ...   ...   ...          ...                             ...
# 218   NaN   NaN   NaN          NaN                        Thailand
# 219   NaN   NaN   NaN          NaN                      Tajikistan
# 220   NaN   NaN   NaN          NaN                    Turkmenistan
# 221   NaN   NaN   NaN          NaN                     Timor-Leste
# 222   NaN   NaN   NaN          NaN                           Tonga
# 223   NaN   NaN   NaN          NaN             Trinidad and Tobago
# 224   NaN   NaN   NaN          NaN                         Tunisia
# 225   NaN   NaN   NaN          NaN                          Turkey
# 226   NaN   NaN   NaN          NaN                          Tuvalu
# 227   NaN   NaN   NaN          NaN                   Taiwan, China
# 228   NaN   NaN   NaN          NaN                        Tanzania
# 229   NaN   NaN   NaN          NaN                          Uganda
# 230   NaN   NaN   NaN          NaN                         Ukraine
# 231   NaN   NaN   NaN          NaN             Upper middle income
# 232   NaN   NaN   NaN          NaN                         Uruguay
# 233   NaN   NaN   NaN          NaN                   United States
# 234   NaN   NaN   NaN          NaN                      Uzbekistan
# 235   NaN   NaN   NaN          NaN  St. Vincent and the Grenadines
# 236   NaN   NaN   NaN          NaN                   Venezuela, RB
# 237   NaN   NaN   NaN          NaN           Virgin Islands (U.S.)
# 238   NaN   NaN   NaN          NaN                         Vietnam
# 239   NaN   NaN   NaN          NaN                         Vanuatu
# 240   NaN   NaN   NaN          NaN              West Bank and Gaza
# 241   NaN   NaN   NaN          NaN                           World
# 242   NaN   NaN   NaN          NaN                           Samoa
# 243   NaN   NaN   NaN          NaN                     Yemen, Rep.
# 244   NaN   NaN   NaN          NaN                    South Africa
# 245   NaN   NaN   NaN          NaN                Congo, Dem. Rep.
# 246   NaN   NaN   NaN          NaN                          Zambia
# 247   NaN   NaN   NaN          NaN                        Zimbabwe
#
#                          Region           IncomeGroup  \
# 0     Latin America & Caribbean  High income: nonOECD
# 1         Europe & Central Asia  High income: nonOECD
# 2                    South Asia            Low income
# 3            Sub-Saharan Africa   Upper middle income
# 4         Europe & Central Asia   Upper middle income
# 5                           NaN                   NaN
# 6    Middle East & North Africa  High income: nonOECD
# 7     Latin America & Caribbean  High income: nonOECD
# 8         Europe & Central Asia   Lower middle income
# 9           East Asia & Pacific   Upper middle income
# 10    Latin America & Caribbean  High income: nonOECD
# 11          East Asia & Pacific     High income: OECD
# 12        Europe & Central Asia     High income: OECD
# 13        Europe & Central Asia   Upper middle income
# 14           Sub-Saharan Africa            Low income
# 15        Europe & Central Asia     High income: OECD
# 16           Sub-Saharan Africa            Low income
# 17           Sub-Saharan Africa            Low income
# 18                   South Asia   Lower middle income
# 19        Europe & Central Asia   Upper middle income
# 20   Middle East & North Africa  High income: nonOECD
# 21    Latin America & Caribbean  High income: nonOECD
# 22        Europe & Central Asia   Upper middle income
# 23        Europe & Central Asia   Upper middle income
# 24    Latin America & Caribbean   Upper middle income
# 25                North America  High income: nonOECD
# 26    Latin America & Caribbean   Lower middle income
# 27    Latin America & Caribbean   Upper middle income
# 28    Latin America & Caribbean  High income: nonOECD
# 29          East Asia & Pacific  High income: nonOECD
# ..                          ...                   ...
# 218         East Asia & Pacific   Upper middle income
# 219       Europe & Central Asia   Lower middle income
# 220       Europe & Central Asia   Upper middle income
# 221         East Asia & Pacific   Lower middle income
# 222         East Asia & Pacific   Upper middle income
# 223   Latin America & Caribbean  High income: nonOECD
# 224  Middle East & North Africa   Upper middle income
# 225       Europe & Central Asia   Upper middle income
# 226         East Asia & Pacific   Upper middle income
# 227         East Asia & Pacific  High income: nonOECD
# 228          Sub-Saharan Africa            Low income
# 229          Sub-Saharan Africa            Low income
# 230       Europe & Central Asia   Lower middle income
# 231                         NaN                   NaN
# 232   Latin America & Caribbean  High income: nonOECD
# 233               North America     High income: OECD
# 234       Europe & Central Asia   Lower middle income
# 235   Latin America & Caribbean   Upper middle income
# 236   Latin America & Caribbean  High income: nonOECD
# 237   Latin America & Caribbean  High income: nonOECD
# 238         East Asia & Pacific   Lower middle income
# 239         East Asia & Pacific   Lower middle income
# 240  Middle East & North Africa   Lower middle income
# 241                         NaN                   NaN
# 242         East Asia & Pacific   Lower middle income
# 243  Middle East & North Africa   Lower middle income
# 244          Sub-Saharan Africa   Upper middle income
# 245          Sub-Saharan Africa            Low income
# 246          Sub-Saharan Africa   Lower middle income
# 247          Sub-Saharan Africa            Low income
#
#                                           SpecialNotes  Unnamed: 5
# 0    SNA data for 2000-2011 are updated from offici...         NaN
# 1                                                  NaN         NaN
# 2    Fiscal year end: March 20; reporting period fo...         NaN
# 3    April 2013 database update: Based on IMF data,...         NaN
# 4                                                  NaN         NaN
# 5    Arab World aggregate. Arab World is composed o...         NaN
# 6    April 2013 database update: Based on data from...         NaN
# 7                   The base year has changed to 2004.         NaN
# 8                                                  NaN         NaN
# 9                                                  NaN         NaN
# 10   April 2012 database update: Based on official ...         NaN
# 11   Fiscal year end: June 30; reporting period for...         NaN
# 12   A simple multiplier is used to convert the nat...         NaN
# 13   April 2012 database update: National accounts ...         NaN
# 14                                                 NaN         NaN
# 15   A simple multiplier is used to convert the nat...         NaN
# 16                                                 NaN         NaN
# 17                                                 NaN         NaN
# 18   Fiscal year end: June 30; reporting period for...         NaN
# 19   The new reference year for chain linked series...         NaN
# 20   Based on official government statistics; the n...         NaN
# 21                                                 NaN         NaN
# 22   Based on official government statistics for ch...         NaN
# 23                                                 NaN         NaN
# 24                                                 NaN         NaN
# 25                                                 NaN         NaN
# 26                                                 NaN         NaN
# 27                                                 NaN         NaN
# 28                                                 NaN         NaN
# 29                                                 NaN         NaN
# ..                                                 ...         ...
# 218  Fiscal year end: September 30; reporting perio...         NaN
# 219                                                NaN         NaN
# 220  On January 1, 2009, the Turkmen manat was rede...         NaN
# 221  Based on official government statistics, natio...         NaN
# 222  2013 national accounts estimates are based on ...         NaN
# 223                                                NaN         NaN
# 224  National accounts data from 2005 onward have b...         NaN
# 225                                                NaN         NaN
# 226  2013 national accounts estimates are based on ...         NaN
# 227                                                NaN         NaN
# 228  The new base year is 2007. Tanzania reports us...         NaN
# 229  Fiscal year end: June 30; reporting period for...         NaN
# 230                                                NaN         NaN
# 231  Upper middle income group aggregate. Upper-mid...         NaN
# 232  In 2011, the Central Bank revised national acc...         NaN
# 233  Fiscal year end: September 30; reporting perio...         NaN
# 234                                                NaN         NaN
# 235  April 2012 database update: Based on official ...         NaN
# 236                                                NaN         NaN
# 237                                                NaN         NaN
# 238  Based on data from the Vietnam Statistics Offi...         NaN
# 239  2013 national accounts estimates are based on ...         NaN
# 240                         The new base year is 2004.         NaN
# 241                                   World aggregate.         NaN
# 242  Fiscal year ends on June 30; reporting period ...         NaN
# 243  Based on official government statistics and In...         NaN
# 244  Fiscal year end: March 31; reporting period fo...         NaN
# 245  Based on official government statistics; the n...         NaN
# 246  The new base year is 2010. National accounts d...         NaN
# 247  Fiscal year end: June 30; reporting period for...         NaN
#
# [248 rows x 66 columns]

# %% [markdown]
# **注意:** 当某一行不是实际的国家时，'Region'的值就是 NaN.

# %% [markdown]
# #### 移除 `Region` 为 NaN 的行

# %%
merge = merge[pd.notnull(merge['Region'])]

# %%
merge
# Out:
#                      Country Name_x Country Code  \
# 0                             Aruba          ABW
# 1                           Andorra          AND
# 2                       Afghanistan          AFG
# 3                            Angola          AGO
# 4                           Albania          ALB
# 6              United Arab Emirates          ARE
# 7                         Argentina          ARG
# 8                           Armenia          ARM
# 9                    American Samoa          ASM
# 10              Antigua and Barbuda          ATG
# 11                        Australia          AUS
# 12                          Austria          AUT
# 13                       Azerbaijan          AZE
# 14                          Burundi          BDI
# 15                          Belgium          BEL
# 16                            Benin          BEN
# 17                     Burkina Faso          BFA
# 18                       Bangladesh          BGD
# 19                         Bulgaria          BGR
# 20                          Bahrain          BHR
# 21                     Bahamas, The          BHS
# 22           Bosnia and Herzegovina          BIH
# 23                          Belarus          BLR
# 24                           Belize          BLZ
# 25                          Bermuda          BMU
# 26                          Bolivia          BOL
# 27                           Brazil          BRA
# 28                         Barbados          BRB
# 29                Brunei Darussalam          BRN
# 30                           Bhutan          BTN
# ..                              ...          ...
# 216                            Chad          TCD
# 217                            Togo          TGO
# 218                        Thailand          THA
# 219                      Tajikistan          TJK
# 220                    Turkmenistan          TKM
# 221                     Timor-Leste          TLS
# 222                           Tonga          TON
# 223             Trinidad and Tobago          TTO
# 224                         Tunisia          TUN
# 225                          Turkey          TUR
# 226                          Tuvalu          TUV
# 227                   Taiwan, China          TWN
# 228                        Tanzania          TZA
# 229                          Uganda          UGA
# 230                         Ukraine          UKR
# 232                         Uruguay          URY
# 233                   United States          USA
# 234                      Uzbekistan          UZB
# 235  St. Vincent and the Grenadines          VCT
# 236                   Venezuela, RB          VEN
# 237           Virgin Islands (U.S.)          VIR
# 238                         Vietnam          VNM
# 239                         Vanuatu          VUT
# 240              West Bank and Gaza          PSE
# 242                           Samoa          WSM
# 243                     Yemen, Rep.          YEM
# 244                    South Africa          ZAF
# 245                Congo, Dem. Rep.          COD
# 246                          Zambia          ZMB
# 247                        Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code       1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.046068
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.104357
# 4    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.258195
# 6    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.118786
# 7    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.367473
# 8    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 9    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 10   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.670617
# 11   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   8.582937
# 12   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.373319
# 13   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 14   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 15   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   9.941594
# 16   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.066354
# 17   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.009112
# 18   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 19   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   2.833901
# 20   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.542864
# 21   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.749831
# 22   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 23   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 24   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.477951
# 25   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.551374
# 26   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.272038
# 27   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.647068
# 28   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.746313
# 29   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.078179
# 30   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# ..                                      ...             ...        ...
# 216  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.018319
# 217  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.041762
# 218  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135586
# 219  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 220  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 221  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 222  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.178588
# 223  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.042576
# 224  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.409211
# 225  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.610473
# 226  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 227  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 228  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.082261
# 229  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.062123
# 230  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 232  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.701583
# 233  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  15.999779
# 234  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 235  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135902
# 236  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   7.005107
# 237  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 238  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.215631
# 239  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 240  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 242  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.135009
# 243  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.703403
# 244  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   5.629718
# 245  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.152228
# 246  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
# 247  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC        NaN
#
#           1961       1962       1963       1964       1965     ...      2012  \
# 0          NaN        NaN        NaN        NaN        NaN     ...       NaN
# 1          NaN        NaN        NaN        NaN        NaN     ...       NaN
# 2     0.053615   0.073781   0.074251   0.086317   0.101499     ...       NaN
# 3     0.084718   0.216025   0.206877   0.216174   0.206089     ...       NaN
# 4     1.374186   1.439956   1.181681   1.111742   1.166099     ...       NaN
# 6     0.108937   0.163355   0.175712   0.132651   0.146370     ...       NaN
# 7     2.442616   2.522392   2.316356   2.538380   2.641714     ...       NaN
# 8          NaN        NaN        NaN        NaN        NaN     ...       NaN
# 9          NaN        NaN        NaN        NaN        NaN     ...       NaN
# 10    0.860441   1.823374   1.470175   1.567094   2.520359     ...       NaN
# 11    8.641569   8.835688   9.226440   9.759073  10.622321     ...       NaN
# 12    4.496362   4.755362   5.155194   5.391004   5.252197     ...       NaN
# 13         NaN        NaN        NaN        NaN        NaN     ...       NaN
# 14         NaN   0.015203   0.016155   0.015827   0.011910     ...       NaN
# 15   10.103872  10.641190  11.386929  11.053655  11.141656     ...       NaN
# 16    0.052046   0.054202   0.047580   0.055295   0.057115     ...       NaN
# 17    0.018730   0.017003   0.017504   0.021575   0.019841     ...       NaN
# 18         NaN        NaN        NaN        NaN        NaN     ...       NaN
# 19    3.269920   3.835892   4.259781   5.262988   5.645652     ...       NaN
# 20   10.547396   9.193609   6.714156   8.747480   6.557022     ...       NaN
# 21    4.746699   5.996432   5.558199   8.118597   9.399946     ...       NaN
# 22         NaN        NaN        NaN        NaN        NaN     ...       NaN
# 23         NaN        NaN        NaN        NaN        NaN     ...       NaN
# 24    0.387219   0.715409   0.622357   0.818289   0.794763     ...       NaN
# 25    3.868484   3.383712   3.151929   4.124438   3.586487     ...       NaN
# 26    0.276621   0.286626   0.310159   0.371216   0.371151     ...       NaN
# 27    0.658625   0.697281   0.700749   0.694001   0.670372     ...       NaN
# 28    0.838899   1.119411   0.816330   0.766085   0.872454     ...       NaN
# 29    3.552009   4.133422   3.798174   3.482289   3.254787     ...       NaN
# 30         NaN        NaN        NaN        NaN        NaN     ...       NaN
# ..         ...        ...        ...        ...        ...     ...       ...
# 216   0.016769   0.027012   0.028785   0.030485   0.032119     ...       NaN
# 217   0.057386   0.054570   0.065171   0.079426   0.077262     ...       NaN
# 218   0.146944   0.173130   0.185877   0.242240   0.234151     ...       NaN
# 219        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 220        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 221        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 222   0.172592   0.166040   0.159435   0.153309   0.147936     ...       NaN
# 223   5.318141   8.225570   1.466683   4.201774   5.694904     ...       NaN
# 224   0.413220   0.412987   0.438885   0.608626   0.532230     ...       NaN
# 225   0.615079   0.748241   0.765934   0.869390   0.883506     ...       NaN
# 226        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 227        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 228   0.067872   0.071734   0.072968   0.091197   0.099494     ...       NaN
# 229   0.058093   0.059258   0.057791   0.063435   0.078242     ...       NaN
# 230        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 232   1.602723   1.540657   1.639285   1.710101   2.049519     ...       NaN
# 233  15.681256  16.013937  16.482762  16.968119  17.451725     ...       NaN
# 234        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 235   0.133923   0.132214   0.174273   0.215513   0.170614     ...       NaN
# 236   6.136886   6.155057   6.155748   5.973226   6.187252     ...       NaN
# 237        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 238   0.225435   0.258760   0.247579   0.314058   0.343354     ...       NaN
# 239        NaN   0.594888   0.471728   0.864247   0.641714     ...       NaN
# 240        NaN        NaN        NaN        NaN        NaN     ...       NaN
# 242   0.163529   0.158352   0.184019   0.208092   0.230869     ...       NaN
# 243   0.507631   0.728004   0.537606   0.658012   0.699574     ...       NaN
# 244   5.694383   5.729712   5.799844   6.170936   6.467359     ...       NaN
# 245   0.150782   0.135559   0.139446   0.116926   0.142290     ...       NaN
# 246        NaN        NaN        NaN   0.950434   1.100197     ...       NaN
# 247        NaN        NaN        NaN   1.045374   1.179176     ...       NaN
#
#      2013  2014  2015  Unnamed: 60                  Country Name_y  \
# 0     NaN   NaN   NaN          NaN                           Aruba
# 1     NaN   NaN   NaN          NaN                         Andorra
# 2     NaN   NaN   NaN          NaN                     Afghanistan
# 3     NaN   NaN   NaN          NaN                          Angola
# 4     NaN   NaN   NaN          NaN                         Albania
# 6     NaN   NaN   NaN          NaN            United Arab Emirates
# 7     NaN   NaN   NaN          NaN                       Argentina
# 8     NaN   NaN   NaN          NaN                         Armenia
# 9     NaN   NaN   NaN          NaN                  American Samoa
# 10    NaN   NaN   NaN          NaN             Antigua and Barbuda
# 4         Europe & Central Asia   Upper middle income
# 6    Middle East & North Africa  High income: nonOECD
# 7     Latin America & Caribbean  High income: nonOECD
# 8         Europe & Central Asia   Lower middle income
# 9           East Asia & Pacific   Upper middle income
# 10    Latin America & Caribbean  High income: nonOECD
# 11          East Asia & Pacific     High income: OECD
# 12        Europe & Central Asia     High income: OECD
# 13        Europe & Central Asia   Upper middle income
# 14           Sub-Saharan Africa            Low income
# 15        Europe & Central Asia     High income: OECD
# 16           Sub-Saharan Africa            Low income
# 17           Sub-Saharan Africa            Low income
# 18                   South Asia   Lower middle income
# 19        Europe & Central Asia   Upper middle income
# 20   Middle East & North Africa  High income: nonOECD
# 21    Latin America & Caribbean  High income: nonOECD
# 22        Europe & Central Asia   Upper middle income
# 23        Europe & Central Asia   Upper middle income
# 24    Latin America & Caribbean   Upper middle income
# 25                North America  High income: nonOECD
# 26    Latin America & Caribbean   Lower middle income
# 27    Latin America & Caribbean   Upper middle income
# 28    Latin America & Caribbean  High income: nonOECD
# 29          East Asia & Pacific  High income: nonOECD
# 30                   South Asia   Lower middle income
# ..                          ...                   ...
# 216          Sub-Saharan Africa            Low income
# 217          Sub-Saharan Africa            Low income
# 218         East Asia & Pacific   Upper middle income
# 219       Europe & Central Asia   Lower middle income
# 220       Europe & Central Asia   Upper middle income
# 221         East Asia & Pacific   Lower middle income
# 222         East Asia & Pacific   Upper middle income
# 223   Latin America & Caribbean  High income: nonOECD
# 224  Middle East & North Africa   Upper middle income
# 225       Europe & Central Asia   Upper middle income
# 226         East Asia & Pacific   Upper middle income
# 227         East Asia & Pacific  High income: nonOECD
# 228          Sub-Saharan Africa            Low income
# 229          Sub-Saharan Africa            Low income
# 230       Europe & Central Asia   Lower middle income
# 232   Latin America & Caribbean  High income: nonOECD
# 233               North America     High income: OECD
# 234       Europe & Central Asia   Lower middle income
# 235   Latin America & Caribbean   Upper middle income
# 236   Latin America & Caribbean  High income: nonOECD
# 237   Latin America & Caribbean  High income: nonOECD
# 238         East Asia & Pacific   Lower middle income
# 239         East Asia & Pacific   Lower middle income
# 240  Middle East & North Africa   Lower middle income
# 242         East Asia & Pacific   Lower middle income
# 243  Middle East & North Africa   Lower middle income
# 244          Sub-Saharan Africa   Upper middle income
# 245          Sub-Saharan Africa            Low income
# 246          Sub-Saharan Africa   Lower middle income
# 247          Sub-Saharan Africa            Low income
#
#                                           SpecialNotes  Unnamed: 5
# 0    SNA data for 2000-2011 are updated from offici...         NaN
# 1                                                  NaN         NaN
# 2    Fiscal year end: March 20; reporting period fo...         NaN
# 3    April 2013 database update: Based on IMF data,...         NaN
# 4                                                  NaN         NaN
# 6    April 2013 database update: Based on data from...         NaN
# 7                   The base year has changed to 2004.         NaN
# 8                                                  NaN         NaN
# 9                                                  NaN         NaN
# 10   April 2012 database update: Based on official ...         NaN
# 11   Fiscal year end: June 30; reporting period for...         NaN
# 12   A simple multiplier is used to convert the nat...         NaN
# 13   April 2012 database update: National accounts ...         NaN
# 14                                                 NaN         NaN
# 15   A simple multiplier is used to convert the nat...         NaN
# 16                                                 NaN         NaN
# 17                                                 NaN         NaN
# 18   Fiscal year end: June 30; reporting period for...         NaN
# 19   The new reference year for chain linked series...         NaN
# 20   Based on official government statistics; the n...         NaN
# 21                                                 NaN         NaN
# 22   Based on official government statistics for ch...         NaN
# 23                                                 NaN         NaN
# 24                                                 NaN         NaN
# 25                                                 NaN         NaN
# 26                                                 NaN         NaN
# 27                                                 NaN         NaN
# 28                                                 NaN         NaN
# 29                                                 NaN         NaN
# 30   April 2013 database update: Data were updated ...         NaN
# ..                                                 ...         ...
# 216  Based on IMF data, national accounts data have...         NaN
# 217  April 2013 database update: Based on IMF data,...         NaN
# 218  Fiscal year end: September 30; reporting perio...         NaN
# 219                                                NaN         NaN
# 220  On January 1, 2009, the Turkmen manat was rede...         NaN
# 221  Based on official government statistics, natio...         NaN
# 222  2013 national accounts estimates are based on ...         NaN
# 223                                                NaN         NaN
# 224  National accounts data from 2005 onward have b...         NaN
# 225                                                NaN         NaN
# 226  2013 national accounts estimates are based on ...         NaN
# 227                                                NaN         NaN
# 228  The new base year is 2007. Tanzania reports us...         NaN
# 229  Fiscal year end: June 30; reporting period for...         NaN
# 230                                                NaN         NaN
# 232  In 2011, the Central Bank revised national acc...         NaN
# 233  Fiscal year end: September 30; reporting perio...         NaN
# 234                                                NaN         NaN
# 235  April 2012 database update: Based on official ...         NaN
# 236                                                NaN         NaN
# 237                                                NaN         NaN
# 238  Based on data from the Vietnam Statistics Offi...         NaN
# 239  2013 national accounts estimates are based on ...         NaN
# 240                         The new base year is 2004.         NaN
# 242  Fiscal year ends on June 30; reporting period ...         NaN
# 243  Based on official government statistics and In...         NaN
# 244  Fiscal year end: March 31; reporting period fo...         NaN
# 245  Based on official government statistics; the n...         NaN
# 246  The new base year is 2010. National accounts d...         NaN
# 247  Fiscal year end: June 30; reporting period for...         NaN
#
# [215 rows x 66 columns]

# %% [markdown]
# <br>

# %% [markdown]
# <h2>2. 有些列是不相关的，可以被移除.</h2>

# %% [markdown]
# **目标:**
# 移除下列不相关的列:
# - 第 3 列: **"Indicator Name"**
# - 第 4 列: **"Indicator Code"**

# %%
merge.columns
# Out:
# Index(['Country Name_x', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', 'Unnamed: 60', 'Country Name_y', 'Region',
#        'IncomeGroup', 'SpecialNotes', 'Unnamed: 5'],
#       dtype='object')

# %%
? merge.drop

# %%
merge = merge.drop(merge.columns[[60,65]], axis=1) # Note: zero indexed
merge = merge.drop('Indicator Name', axis=1)
merge = merge.drop('Indicator Code', 1)

# %%
merge.columns
# Out:
# Index(['Country Name_x', 'Country Code', '1960', '1961', '1962', '1963',
#        '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972',
#        '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990',
#        '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        'Country Name_y', 'Region', 'IncomeGroup', 'SpecialNotes'],
#       dtype='object')

# %% [markdown]
# <h2>3. 有些年份对于任何国家都没有数据.</h2>

# %% [markdown]
# **目标:**
# 计算每一年的数据行数，NaN值不计算在内.

# %%
merge.count()
# Out:
# Country Name_x    215
# Country Code      215
# 1960              151
# 1961              152
# 1962              153
# 1963              154
# 1964              159
# 1965              159
# 1966              159
# 1967              159
# 1968              158
# 1969              159
# 1970              161
# 1971              162
# 1972              164
# 1973              164
# 1974              164
# 1975              164
# 1976              164
# 1977              164
# 1978              164
# 1979              164
# 1980              164
# 1981              164
# 1982              164
# 1983              164
# 1984              164
# 1985              164
# 1986              165
# 1987              165
#                  ...
# 1990              167
# 1991              168
# 1992              188
# 1993              188
# 1994              189
# 1995              192
# 1996              191
# 1997              193
# 1998              193
# 1999              193
# 2000              194
# 2001              194
# 2002              195
# 2003              195
# 2004              195
# 2005              197
# 2006              198
# 2007              199
# 2008              199
# 2009              199
# 2010              199
# 2011              199
# 2012                0
# 2013                0
# 2014                0
# 2015                0
# Country Name_y    215
# Region            215
# IncomeGroup       215
# SpecialNotes      136
# Length: 62, dtype: int64

# %% [markdown]
# 查看2015年，看起来所有行都不包含2015年的数据.

# %%
merge['2015']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
#        ..
# 216   NaN
# 217   NaN
# 218   NaN
# 219   NaN
# 220   NaN
# 221   NaN
# 222   NaN
# 223   NaN
# 224   NaN
# 225   NaN
# 226   NaN
# 227   NaN
# 228   NaN
# 229   NaN
# 230   NaN
# 232   NaN
# 233   NaN
# 234   NaN
# 235   NaN
# 236   NaN
# 237   NaN
# 238   NaN
# 239   NaN
# 240   NaN
# 242   NaN
# 243   NaN
# 244   NaN
# 245   NaN
# 246   NaN
# 247   NaN
# Name: 2015, Length: 215, dtype: float64

# %% [markdown]
# #### 移除任何行都不包含数据的列

# %%
merge = merge.drop(['2012','2013','2014','2015'], axis = 1)

# %%
merge.count() #double-check that columns have been removed
# Out:
# Country Name_x    215
# Country Code      215
# 1960              151
# 1961              152
# 1962              153
# 1963              154
# 1964              159
# 1965              159
# 1966              159
# 1967              159
# 1968              158
# 1969              159
# 1970              161
# 1971              162
# 1972              164
# 1973              164
# 1974              164
# 1975              164
# 1976              164
# 1977              164
# 1978              164
# 1979              164
# 1980              164
# 1981              164
# 1982              164
# 1983              164
# 1984              164
# 1985              164
# 1986              165
# 1987              165
# 1988              165
# 1989              165
# 1990              167
# 1991              168
# 1992              188
# 1993              188
# 1994              189
# 1995              192
# 1996              191
# 1997              193
# 1998              193
# 1999              193
# 2000              194
# 2001              194
# 2002              195
# 2003              195
# 2004              195
# 2005              197
# 2006              198
# 2007              199
# 2008              199
# 2009              199
# 2010              199
# 2011              199
# Country Name_y    215
# Region            215
# IncomeGroup       215
# SpecialNotes      136
# dtype: int64

# %% [markdown]
# <h2>4. 有些国家在任何年份都没有数据.</h2>

# %% [markdown]
# **目标:**
# 使用行平均值来确定哪些国家不包含任何数据.

# %% [markdown]
# 计算每一行的平均值(在 axis 1 上).

# %%
merge.mean(axis=1) #Takes the mean of all numeric quantities by row
# Out:
# 0      21.766264
# 1       6.926680
# 2       0.139113
# 3       0.610377
# 4       1.657433
# 6      31.844877
# 7       3.563240
# 8       1.230824
# 10      5.106829
# 11     14.364944
# 12      7.200894
# 13      4.257653
# 14      0.032397
# 15     11.372211
# 16      0.184605
# 17      0.060372
# 18      0.174804
# 19      7.181894
# 20     19.867874
# 21     12.989496
# 22      3.336662
# 23      6.194563
# 24      1.384584
# 25      7.125285
# 26      0.906155
# 27      1.406963
# 28      3.143447
# 29     21.497854
# 30      0.331486
# 31      1.603745
#          ...
# 213     3.217774
# 214     2.300493
# 215     3.412094
# 216     0.031805
# 217     0.197678
# 218     1.726478
# 219     0.459464
# 220     8.943359
# 221     0.177336
# 222     0.630603
# 223    15.802071
# 224     1.482407
# 225     2.310214
# 228     0.114896
# 229     0.073733
# 230     7.434661
# 232     1.742226
# 233    19.303472
# 234     4.623481
# 235     0.870765
# 236     5.959301
# 238     0.598837
# 239     0.517542
# 240     0.471235
# 242     0.612593
# 243     0.737396
# 244     8.230187
# 245     0.104890
# 246     0.495172
# 247     1.228627
# Length: 199, dtype: float64

# %% [markdown]
# 正如你所见，在不包含任何数据的行中出现了 NaN.

# %% [markdown]
# #### 移除所有年份中不包含任何数据的行

# %%
merge = merge[pd.notnull(merge.mean(axis=1))]

# %% [markdown]
# <hr>

# %% [markdown]
# <h2, align = "center">数据清洗 ... 完成!</h2>

# %% [markdown]
# ### 为了方便起见，重新命名

# %%
mydf = merge
mydf
# Out:
#                      Country Name_x Country Code       1960       1961  \
# 0                             Aruba          ABW        NaN        NaN
# 1                           Andorra          AND        NaN        NaN
# 2                       Afghanistan          AFG   0.046068   0.053615
# 3                            Angola          AGO   0.104357   0.084718
# 4                           Albania          ALB   1.258195   1.374186
# 6              United Arab Emirates          ARE   0.118786   0.108937
# 7                         Argentina          ARG   2.367473   2.442616
# 8                           Armenia          ARM        NaN        NaN
# 10              Antigua and Barbuda          ATG   0.670617   0.860441
# 11                        Australia          AUS   8.582937   8.641569
# 12                          Austria          AUT   4.373319   4.496362
# 13                       Azerbaijan          AZE        NaN        NaN
# 14                          Burundi          BDI        NaN        NaN
# 15                          Belgium          BEL   9.941594  10.103872
# 16                            Benin          BEN   0.066354   0.052046
# 17                     Burkina Faso          BFA   0.009112   0.018730
# 18                       Bangladesh          BGD        NaN        NaN
# 19                         Bulgaria          BGR   2.833901   3.269920
# 20                          Bahrain          BHR   3.542864  10.547396
# 21                     Bahamas, The          BHS   3.749831   4.746699
# 22           Bosnia and Herzegovina          BIH        NaN        NaN
# 23                          Belarus          BLR        NaN        NaN
# 24                           Belize          BLZ   0.477951   0.387219
# 25                          Bermuda          BMU   3.551374   3.868484
# 26                          Bolivia          BOL   0.272038   0.276621
# 27                           Brazil          BRA   0.647068   0.658625
# 28                         Barbados          BRB   0.746313   0.838899
# 29                Brunei Darussalam          BRN   4.078179   3.552009
# 30                           Bhutan          BTN        NaN        NaN
# 31                         Botswana          BWA        NaN        NaN
# ..                              ...          ...        ...        ...
# 213                      Seychelles          SYC        NaN        NaN
# 214            Syrian Arab Republic          SYR   0.701818   0.646400
# 215        Turks and Caicos Islands          TCA        NaN        NaN
# 216                            Chad          TCD   0.018319   0.016769
# 217                            Togo          TGO   0.041762   0.057386
# 218                        Thailand          THA   0.135586   0.146944
# 219                      Tajikistan          TJK        NaN        NaN
# 220                    Turkmenistan          TKM        NaN        NaN
# 221                     Timor-Leste          TLS        NaN        NaN
# 222                           Tonga          TON   0.178588   0.172592
# 223             Trinidad and Tobago          TTO   3.042576   5.318141
# 224                         Tunisia          TUN   0.409211   0.413220
# 225                          Turkey          TUR   0.610473   0.615079
# 228                        Tanzania          TZA   0.082261   0.067872
# 229                          Uganda          UGA   0.062123   0.058093
# 230                         Ukraine          UKR        NaN        NaN
# 232                         Uruguay          URY   1.701583   1.602723
# 233                   United States          USA  15.999779  15.681256
# 234                      Uzbekistan          UZB        NaN        NaN
# 235  St. Vincent and the Grenadines          VCT   0.135902   0.133923
# 236                   Venezuela, RB          VEN   7.005107   6.136886
# 238                         Vietnam          VNM   0.215631   0.225435
# 239                         Vanuatu          VUT        NaN        NaN
# 240              West Bank and Gaza          PSE        NaN        NaN
# 242                           Samoa          WSM   0.135009   0.163529
# 243                     Yemen, Rep.          YEM   0.703403   0.507631
# 244                    South Africa          ZAF   5.629718   5.694383
# 245                Congo, Dem. Rep.          COD   0.152228   0.150782
# 246                          Zambia          ZMB        NaN        NaN
# 247                        Zimbabwe          ZWE        NaN        NaN
#
#           1962       1963       1964       1965       1966       1967  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2     0.073781   0.074251   0.086317   0.101499   0.107674   0.123782
# 3     0.216025   0.206877   0.216174   0.206089   0.265164   0.166659
# 4     1.439956   1.181681   1.111742   1.166099   1.333055   1.363746
# 6     0.163355   0.175712   0.132651   0.146370   0.159359   5.336737
# 7     2.522392   2.316356   2.538380   2.641714   2.792654   2.858163
# 8          NaN        NaN        NaN        NaN        NaN        NaN
# 10    1.823374   1.470175   1.567094   2.520359   5.727992   9.108061
# 11    8.835688   9.226440   9.759073  10.622321  10.328092  10.955625
# 12    4.755362   5.155194   5.391004   5.252197   5.361725   5.417737
# 13         NaN        NaN        NaN        NaN        NaN        NaN
# 14    0.015203   0.016155   0.015827   0.011910   0.015115   0.014735
# 15   10.641190  11.386929  11.053655  11.141656  11.042019  11.217257
# 16    0.054202   0.047580   0.055295   0.057115   0.042395   0.052320
# 17    0.017003   0.017504   0.021575   0.019841   0.019534   0.019217
# 18         NaN        NaN        NaN        NaN        NaN        NaN
# 19    3.835892   4.259781   5.262988   5.645652   5.905437   6.638369
# 20    9.193609   6.714156   8.747480   6.557022   3.384358   5.121012
# 21    5.996432   5.558199   8.118597   9.399946   7.466085  11.173504
# 22         NaN        NaN        NaN        NaN        NaN        NaN
# 23         NaN        NaN        NaN        NaN        NaN        NaN
# 31                         Botswana          Sub-Saharan Africa
# ..                              ...                         ...
# 213                      Seychelles          Sub-Saharan Africa
# 214            Syrian Arab Republic  Middle East & North Africa
# 215        Turks and Caicos Islands   Latin America & Caribbean
# 216                            Chad          Sub-Saharan Africa
# 217                            Togo          Sub-Saharan Africa
# 218                        Thailand         East Asia & Pacific
# 219                      Tajikistan       Europe & Central Asia
# 220                    Turkmenistan       Europe & Central Asia
# 221                     Timor-Leste         East Asia & Pacific
# 222                           Tonga         East Asia & Pacific
# 223             Trinidad and Tobago   Latin America & Caribbean
# 224                         Tunisia  Middle East & North Africa
# 225                          Turkey       Europe & Central Asia
# 228                        Tanzania          Sub-Saharan Africa
# 229                          Uganda          Sub-Saharan Africa
# 230                         Ukraine       Europe & Central Asia
# 232                         Uruguay   Latin America & Caribbean
# 233                   United States               North America
# 234                      Uzbekistan       Europe & Central Asia
# 235  St. Vincent and the Grenadines   Latin America & Caribbean
# 236                   Venezuela, RB   Latin America & Caribbean
# 238                         Vietnam         East Asia & Pacific
# 239                         Vanuatu         East Asia & Pacific
# 240              West Bank and Gaza  Middle East & North Africa
# 242                           Samoa         East Asia & Pacific
# 243                     Yemen, Rep.  Middle East & North Africa
# 244                    South Africa          Sub-Saharan Africa
# 245                Congo, Dem. Rep.          Sub-Saharan Africa
# 246                          Zambia          Sub-Saharan Africa
# 247                        Zimbabwe          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1    High income: nonOECD                                                NaN
# 2              Low income  Fiscal year end: March 20; reporting period fo...
# 3     Upper middle income  April 2013 database update: Based on IMF data,...
# 4     Upper middle income                                                NaN
# 6    High income: nonOECD  April 2013 database update: Based on data from...
# 7    High income: nonOECD                 The base year has changed to 2004.
# 8     Lower middle income                                                NaN
# 10   High income: nonOECD  April 2012 database update: Based on official ...
# 11      High income: OECD  Fiscal year end: June 30; reporting period for...
# 12      High income: OECD  A simple multiplier is used to convert the nat...
# 13    Upper middle income  April 2012 database update: National accounts ...
# 14             Low income                                                NaN
# 15      High income: OECD  A simple multiplier is used to convert the nat...
# 16             Low income                                                NaN
# 17             Low income                                                NaN
# 18    Lower middle income  Fiscal year end: June 30; reporting period for...
# 19    Upper middle income  The new reference year for chain linked series...
# 20   High income: nonOECD  Based on official government statistics; the n...
# 21   High income: nonOECD                                                NaN
# 22    Upper middle income  Based on official government statistics for ch...
# 23    Upper middle income                                                NaN
# 24    Upper middle income                                                NaN
# 25   High income: nonOECD                                                NaN
# 26    Lower middle income                                                NaN
# 27    Upper middle income                                                NaN
# 28   High income: nonOECD                                                NaN
# 29   High income: nonOECD                                                NaN
# 30    Lower middle income  April 2013 database update: Data were updated ...
# 31    Upper middle income  Fiscal year end: March 31; reporting period fo...
# ..                    ...                                                ...
# 213  High income: nonOECD  April 2013 database update: Based on official ...
# 214   Lower middle income  April 2013 database update: Based on data from...
# 215  High income: nonOECD                                                NaN
# 216            Low income  Based on IMF data, national accounts data have...
# 217            Low income  April 2013 database update: Based on IMF data,...
# 218   Upper middle income  Fiscal year end: September 30; reporting perio...
# 219   Lower middle income                                                NaN
# 220   Upper middle income  On January 1, 2009, the Turkmen manat was rede...
# 221   Lower middle income  Based on official government statistics, natio...
# 222   Upper middle income  2013 national accounts estimates are based on ...
# 223  High income: nonOECD                                                NaN
# 224   Upper middle income  National accounts data from 2005 onward have b...
# 225   Upper middle income                                                NaN
# 228            Low income  The new base year is 2007. Tanzania reports us...
# 229            Low income  Fiscal year end: June 30; reporting period for...
# 230   Lower middle income                                                NaN
# 232  High income: nonOECD  In 2011, the Central Bank revised national acc...
# 233     High income: OECD  Fiscal year end: September 30; reporting perio...
# 234   Lower middle income                                                NaN
# 235   Upper middle income  April 2012 database update: Based on official ...
# 236  High income: nonOECD                                                NaN
# 238   Lower middle income  Based on data from the Vietnam Statistics Offi...
# 239   Lower middle income  2013 national accounts estimates are based on ...
# 240   Lower middle income                         The new base year is 2004.
# 242   Lower middle income  Fiscal year ends on June 30; reporting period ...
# 243   Lower middle income  Based on official government statistics and In...
# 244   Upper middle income  Fiscal year end: March 31; reporting period fo...
# 245            Low income  Based on official government statistics; the n...
# 246   Lower middle income  The new base year is 2010. National accounts d...
# 247            Low income  Fiscal year end: June 30; reporting period for...
#
# [199 rows x 58 columns]

# %% [markdown]
# <hr>

# %% [markdown]
# 代码汇总:

# %%
import pandas as pd

#Download data
#!wget --output-document co2emissions.csv https://ibm.box.com/shared/static/3yzxbbizo49bkl8cnjw15tymzfwkycj4.csv
#!wget --output-document countries_metadata.csv https://ibm.box.com/shared/static/qh3o86mpij17ot7anydcmbwt41lwxvln.csv
    
#Import data
data = pd.read_csv("resources/data/co2emissions.csv", skiprows = 4)
metadata = pd.read_csv("resources/data/countries_metadata.csv", encoding = "utf-8")

#Merge data
merge = pd.merge(data, metadata, on = "Country Code")

#Remove non-country regions
merge = merge[pd.notnull(merge['Region'])]

#Drop some columns with no data
merge = merge.drop(merge.columns[[61,66]], axis=1)
merge = merge.drop(['Indicator Name', 'Indicator Code','2012', '2013', '2014', '2015'], 1)

#Drop some rows with no data
merge = merge[pd.notnull(merge.mean(axis=1))]

#Rename
mydf = merge

# %%
mydf

# %% [markdown]
# 想要导出为 csv 文件?

# %%
mydf.to_csv("resources/data/co2emissions_cleaned.csv", index = False) #See Recent Data for exported csv

# %% [markdown]
# <hr></hr>
# <div class="alert alert-success alertsuccess" style="margin-top: 0px">
# <h4> [tip] 数据清洗的规则来源于对业务的理解 </h4>
# <p></p>
# 从上面的清洗过程我们可以看到，无论是如何区分国家和地区，还是剔除不包含数据的国家，都需要明确的清洗规则，而清洗规则是依靠我们对业务的理解而确定的，单纯从数据本身出发，是无法制定出这样的规则的。
# <li>这再次说明，数据分析是业务驱动的，并且需要业务模型的支持。</li>
# <li>计算机能够帮助我们的，是依靠强大的计算能力来加速数据分析的过程。</li>
# <p></p>
# </div>
# <hr></hr>
